# %%
with open('takipci.txt', 'r', encoding="utf-8") as f:
    veriler = f.readlines()
    
takipci = []
for i in range(len(veriler)):
    if "'in profil resmi\n" in veriler[i]:
        takipci.append(veriler[i+1].replace("\n",""))
len(takipci), takipci
# Out:
# (241,
#  ['ketixie',
#   'wxyldzsymammm',
#   'altpll',
#   'seydacolmekcioglu',
#   'iremminerva',
#   'oykualim00',
#   'mustafa_esnaf',
#   'altunmirza',
#   'tugce.ozdmrr36',
#   'tugggcecaglar',
#   'aemirselcuk',
#   'elifsezinn1',
#   'mydn0',
#   '_burakzr',
#   'sinemakkarr',
#   'guraybugra.e',
#   'nisanbuker',
#   'mr.audiologist7',
#   '_beyzayalcinkaya',
#   'mterdogan_',
#   'eliifkurc',
#   'andayberkulas',
#   'pervviinkaya',
#   'huseyinemir.kabaca',
#   'nilsuusenturkk',
#   'sude_.aydin',
#   'yusufcan.krts',
#   'itis.__mali',
#   'olgunsoyilayda',
#   'zninsesigazetesi',
#   'dnz.karman',
#   'aalbayrakx',
#   'kutsaltekbass',
#   'alperensenell',
#   'snidakorucu',
#   'sslnuslu',
#   'yemrewho',
#   'busrakyollll',
#   'ademylmaz29',
#   'azizeguleryuz',
#   'furkanerzincl',
#   'berkay_karakus_',
#   'ardilipek',
#   'kektkwkfkedkkf',
#   'hatcx_x',
#   'rumeysaydddoogan____',
#   'damlagulldemir',
#   'tamerrcesmecik',
#   'selingenc00',
#   'lilkozmonot',
# ...

# %%
import pandas as pd
df = pd.DataFrame(takipci)
df.to_excel("takipci_yeni.xlsx", index=False)
df1 = pd.read_excel("takipci_eski.xlsx")
df2 = pd.read_excel("takipci_yeni.xlsx")
pd.concat([df1, df2]).drop_duplicates(keep=False)
# Out:
#                      0
# 0              ketixie
# 1        wxyldzsymammm
# 2               altpll
# 3    seydacolmekcioglu
# 4          iremminerva
# ..                 ...
# 236     nevfelgulsever
# 237       bukett_uucar
# 238          ege_topcu
# 239    enginerdematlas
# 240    meliih_kurtoglu
#
# [241 rows x 1 columns]

# %%
with open('takip.txt', 'r', encoding="utf-8") as f:
    veriler = f.readlines()
    
takip = []
for i in range(len(veriler)):
    if "'in profil resmi\n" in veriler[i]:
        takip.append(veriler[i+1].replace("\n",""))
len(takip), takip
# Out:
# (310,
#  ['d0gukanbulut',
#   'ademylmaz29',
#   'oykualim00',
#   'ceyda_mlkc',
#   'elifsezinn1',
#   'elifoztas01',
#   'kardelentozlu',
#   'alperkarabay_',
#   'mydn0',
#   'sahinyapamuhammet',
#   'ozgedemi_',
#   'ilaydaa_sahinn',
#   'ikranurkkurt',
#   'yavuz.gokmen17',
#   'kutsaltekbass',
#   'gultekin_sude',
#   'buseakten',
#   'azizeguleryuz',
#   'ayberk.mercan',
#   'seydacolmekcioglu',
#   'lkorayl',
#   'munirsss',
#   'caglla14',
#   'berkehancicek',
#   'hakanaydemrr',
#   'emiirtuncer',
#   'alifuatcalikk',
#   'zekiyekorukmez',
#   'lelifyldrml',
#   'kgnerdm',
#   'wdilaraw',
#   'tolgahan.tek',
#   'neslihaniz',
#   'ilaydaa_sahiin',
#   'zaaycca',
#   'kaanselimkacar',
#   'mustafaerdtusun',
#   'mbugrap34',
#   'ebraryordan',
#   'gulsum.aleynaa',
#   'maypeline',
#   '_berat.ay',
#   'blgncstr',
#   'altunmirza',
#   'seymagezer_',
#   'meminarslann',
#   'cerenyalcn_',
#   'damlasofioglu',
#   '_sadiyeoztrk',
#   'aycausmak',
#   'alperensenell',
# ...

# %%
import pandas as pd
df = pd.DataFrame(takip)
df.to_excel("takip_yeni.xlsx", index=False)
df1 = pd.read_excel("takip_eski.xlsx")
df2 = pd.read_excel("takip_yeni.xlsx")
pd.concat([df1, df2]).drop_duplicates(keep=False)
# Out:
#                    0
# 0       d0gukanbulut
# 1        ademylmaz29
# 2         oykualim00
# 3         ceyda_mlkc
# 4        elifsezinn1
# ..               ...
# 305     tolunay.oren
# 306            mizah
# 307         trtarsiv
# 308              ufc
# 309  thenotoriousmma
#
# [310 rows x 1 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
pd.concat([df1, df2]).drop_duplicates(keep=False)
# Out:
#                          0
# 219              gizehuehu
# 231           nazlii_gozen
# 234              _apoyldrm
# 235               hasolmaz
# 236              kazulet07
# 237               biyokrat
# 238            tuna_arikan
# 239                 elwind
# 240           belemiroloji
# 241                  kkymn
# 244  sehitmuhammedyilmaz43
# 245        omerserdarozkan
# 246                sllebss
# 247       akrabalargiremez
# 248               tuanaksu
# 250  ybflmezunlartoplulugu
# 251           artem_sachko
# 252           techstriking
# 253            yucelborufl
# 254           maltepeedutr
# 255    cleopatrainkkocaeli
# 256           orhunkayaalp
# 257           sebnem_keser
# 258                artucky
# 259               hckmkdgl
# 260                 btno81
# 261                csnaber
# 262             barisozcan
# 263          eniskirazoglu
# 264      furkanrizademirel
# 265            diamondtema
# 266       yeniigelincringe
# 267            dincerisgel
# ...

# %%
pd.reset_option('display.max_rows')

# %%
pd.concat([df1, df2]).drop_duplicates(keep=False)
# Out:
#                    0
# 219        gizehuehu
# 231     nazlii_gozen
# 234        _apoyldrm
# 235         hasolmaz
# 236        kazulet07
# ..               ...
# 1      wxyldzsymammm
# 89       glebbudnikv
# 127      melike_ksgl
# 180  00jesaicaburn00
# 183   eraysertiskele
#
# [81 rows x 1 columns]
